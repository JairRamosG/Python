# %%
from calculos.basicos.calbasicos import *
from calculos.exre.expoyred import *

# %%
sumar(1,2)
restar(10,1)
dividir(10,10)
expon(2,2)
redondear(9.9)
# Out:
# La suma es igual a 3
# La resta es igual a 9
# La división es igual a 1.0
# 2 elevado a 2 es igual a 4
# 9.9 redoneado es igual a 10
